# %% [markdown]
# # Initial Script

# %% [markdown]
# ## Imports

# %%
import handler
import filters

# %%
import numpy as np # for debugging purposes

# %% [markdown]
# ## Load Image

# %%
img, _ = handler.getImageAsArray(handler.FOETUS_PATH_ORIGINAL)

# %% [markdown]
# ## Create and Apply Mean Filter

# %%
meanie = filters.Mean(maskSize=5)
print(meanie)

# %%
imgFiltered = meanie.convolve(img)

# %%
handler.plotFigs([img, imgFiltered])

# %%
handler.saveAll(imgFiltered, meanie)

# %% [markdown]
# ## Create and Apply Gaussian Filter

# %%
gaus = filters.Gaussian(sig=3)
print(gaus)

# %%
imgFiltered = gaus.convolve(img)

# %%
handler.plotFigs([img, imgFiltered])

# %%
handler.saveAll(imgFiltered, gaus)

# %% [markdown]
# ## Create and Apply Median Filter

# %%
med = filters.Median(maskSize=11)
print(med)

# %%
imgFiltered = med.convolve(img)

# %%
handler.plotFigs([img, imgFiltered])

# %%
handler.saveAll(imgFiltered, med)

# %% [markdown]
# ## Create and Apply High Pass Filter

# %%
highP = filters.HighPass(maskSize=9)
print(highP)

# %%
imgFiltered = highP.convolve(img)

# %%
handler.plotFigs([img, imgFiltered])

# %%
handler.saveAll(imgFiltered, highP)

# %% [markdown]
# ## Create and Apply Low Pass Filter

# %%
lowP = filters.LowPass(maskSize=11)
print(lowP)

# %%
imgFiltered = lowP.convolve(img)

# %%
handler.plotFigs([img, imgFiltered])

# %%
handler.saveAll(imgFiltered, lowP)

# %% [markdown]
# ## Create and Apply Adaptive Weighted Median Filter

# %%
awMed = filters.AdaptiveWeightedMedian(maskSize=7)
print(awMed)
# Out:
# Filter name: adaptive-weighted-median,
# Linearity: non-linear,
# Mask size: 7
# Kernel shown below where possible:

# %%
imgFiltered = awMed.convolve(img)
# Out:
#   0%|                                                                                                                                                                                                                                                                                           | 0/758 [00:00<?, ?it/s]
# Padding of 3 pixels created.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 758/758 [01:00<00:00, 12.60it/s]

# %%
handler.plotFigs([img, imgFiltered])

# %%
handler.saveAll(imgFiltered, awMed)
# Out:
# Saved filtered image to...
# C:\Users\Tobias Fechner\Documents\1 - Uni\yr-5\ee40054-digital-image-processing\git_repo\..\outputs\adaptive-weighted-median\maskSize_7\filtered_image.png
#
#
# Saved filtered image to...
# C:\Users\Tobias Fechner\Documents\1 - Uni\yr-5\ee40054-digital-image-processing\git_repo\..\outputs\adaptive-weighted-median\maskSize_7\kernel.png
#
#
# Saved filter object attributes to...
# C:\Users\Tobias Fechner\Documents\1 - Uni\yr-5\ee40054-digital-image-processing\git_repo\..\outputs\adaptive-weighted-median\maskSize_7\filter.txt

# %% [markdown]
# ### START DEBUGGING

# %%
sub = np.round(np.random.rand(25).reshape((5,5))*10)
sub

# %%
awMed.kernel

# %%
# set max weight, used for centre of kernel, and constant
centralWeight = 100
k = 10 #TODO: make configurable

# calculate the standard deviation and mean of sub matrix
std = np.std(sub)
mean = np.mean(sub)

# create matrix of weights based on sub matrix, using formula for adaptive weighted median filter
# truncate negative weights to zero to ensure low pass characteristics
weights = centralWeight - np.divide(k*std*awMed.kernel, mean)
print(weights)

# %% [markdown]
# ### END DEBUGGING
