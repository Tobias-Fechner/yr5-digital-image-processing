# %% [markdown]
# # Initial Script

# %% [markdown]
# ## Imports

# %%
import handler
import filters

# %% [markdown]
# ## Load Image

# %%
img, _ = handler.getImageAsArray(handler.FOETUS_PATH_ORIGINAL)

# %%
handler.plotFigs(img)
# Out:
# <PIL.Image.Image image mode=L size=758x438 at 0x1C2E0ACFDC0>

# %% [markdown]
# ## Create Filter

# %%
meanFilter = filters.Mean(maskSize=9)

# %%
imgFiltered = meanFilter.convolve2D(img)

# %%
handler.plotFigs(imgFiltered)
# Out:
# <PIL.Image.Image image mode=L size=758x438 at 0x1C2E1A7BE50>
